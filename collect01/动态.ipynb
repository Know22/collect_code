# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from lxml import etree
# import time
# import csv

# def user_login(url):#登录
#     web=webdriver.Chrome()
#     web.get(url)
#     time.sleep(3)

#     web.switch_to.frame("login_frame")
#     web.find_element(by=By.ID,value='img_out_392268509').click()
# #     web.find_element(by=By.ID,value='u').send_keys(f'{qq}')
# #     web.find_element(by=By.ID,value='p').send_keys(f'{pa}')
# #     web.find_element(by=By.ID,value='login_button').click()
#     time.sleep(3)
    
#     windows=web.window_handles
#     web.switch_to.window(windows[-1])
#     web.switch_to.frame("mainFrame")
    
#     time.sleep(1)
#     web.find_element(by=By.ID,value='folder_1').click()
#     time.sleep(3)
#     web.switch_to.window(windows[-1])
#     web.switch_to.frame("mainFrame")
#     text=web.page_source
#     with open("E:\\an\\pclass\\爬的内容\\qq邮箱html.txt","w",encoding="utf-8") as f:
#         f.write(text)
#     return text

# info=[]
# def parse(text):#解析
#     tree=etree.HTML(text)
#     for row in tree.xpath('//*[@id="div_showbefore"]/table'):
#         send_name=row.xpath('.//tr/td[3]/table//tr/td[1]/nobr/span/text()')[0]
#         print(send_name)
#         send_email=row.xpath('.//tr/td[3]/table//tr/td[1]/nobr/span/@e')[0]
        
#         send_title=row.xpath('.//tr/td[3]/table//tr/td[3]/div[1]/u/text()')[0]
        
#         send_time=row.xpath('.//tr/td[3]/table//tr/td[4]/div/text()')[0]
        
#         info.append([send_name,send_email,send_title,send_time])
    
# def save_csv(path,item):#将爬取的内容存入csv文件
     
#     with open(path,"w+",newline='',encoding="utf-8-sig") as f:
#         csv_write=csv.writer(f)
#         csv_write.writerow(["发件人","发件人邮箱","邮件标题","收件日期"])
#         csv_write.writerows(item)

# if __name__=="__main__":
#     with open("E:\\an\\pclass\\爬的内容\\qq邮箱html.txt","r",encoding='utf-8') as f:
#         text=f.read()
# #     url='https://mail.qq.com/'
# #     qq='392346789'
# #     pa='wshdpjsn66'
# #     text=user_login(url,qq,pa)
# #     text=user_login(url)
#     parse(text)
#     save_csv("E:\\an\\pclass\\爬的内容\\qq邮箱.csv",info)
# #     print(text)
# Out:
# 2278
# Anaconda Nucleus
# 超级会员项目组
# QQ会员项目组
# QQ空间项目组
# 小西西潮人馆
# 小西西潮人馆
# 张先伟
# QQ邮箱管理员
# QQ邮箱管理员
# QQ邮箱管理员
# noreply
# postmaster
# noreply
# Edith Shaw wSotoYN
# QQ音乐项目组
# eu.photo.gifts/en
# QQ音乐项目组
# QQ安全中心
# QQ邮箱管理员

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from lxml import etree
# import time
# import csv

# def user_login(url):#登录
#     web=webdriver.Chrome()
#     web.get(url,qq,pa)
#     time.sleep(3)

#     web.switch_to.frame("login_frame")
#     web.find_element(by=By.ID,value='u').send_keys(f'{qq}')
#     web.find_element(by=By.ID,value='p').send_keys(f'{pa}')
#     web.find_element(by=By.ID,value='login_button').click()
#     time.sleep(3)
    
#     windows=web.window_handles
#     web.switch_to.window(windows[-1])
#     web.switch_to.frame("mainFrame")
#     time.sleep(1)
    
#     web.find_element(by=By.ID,value='folder_1').click()
#     time.sleep(3)
#     web.switch_to.window(windows[-1])
#     web.switch_to.frame("mainFrame")
#     text=web.page_source

#     return text

# info=[]
# def parse(text):#解析
#     tree=etree.HTML(text)
#     for row in tree.xpath('//*[@id="div_showbefore"]/table'):
#         send_name=row.xpath('.//tr/td[3]/table//tr/td[1]/nobr/span/text()')[0]
        
#         send_email=row.xpath('.//tr/td[3]/table//tr/td[1]/nobr/span/@e')[0]
        
#         send_title=row.xpath('.//tr/td[3]/table//tr/td[3]/div[1]/u/text()')[0]
        
#         send_time=row.xpath('.//tr/td[3]/table//tr/td[4]/div/text()')[0]
        
#         info.append([send_name,send_email,send_title,send_time])
    
# def save_csv(path,item):#将爬取的内容存入csv文件
     
#     with open(path,"w+",newline='',encoding="utf-8-sig") as f:
#         csv_write=csv.writer(f)
#         csv_write.writerow(["发件人","发件人邮箱","邮件标题","收件日期"])
#         csv_write.writerows(item)

# if __name__=="__main__":
#     url='https://mail.qq.com/'
#     qq='392346789'
#     pa='wshdpjsn66'
#     text=user_login(url,qq,pa)
#     parse(text)
#     save_csv("E:\\an\\pclass\\爬的内容\\qq邮箱.csv",info)

# %%
# from selenium.webdriver import Chrome
# import time
# from selenium.webdriver.chrome.options import Options
# #无界面浏览器
# opt=Options()
# opt.add_argument('--headless')
# opt.add_argument('--disable-gpu')
# web=Chrome(options=opt)
# web=Chrome()
# web.get("http://www.baidu.com")
