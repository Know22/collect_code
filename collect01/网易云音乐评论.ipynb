# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from lxml import etree
# import time

# web=webdriver.Chrome()
# url='https://music.163.com/#/artist?id=6452'
# web.get(url)
# time.sleep(3)

# # windows=web.window_handles
# # web.switch_to.window(windows[-1])
# web.switch_to.frame('contentFrame')
# time.sleep(1)
# web.find_element(by=By.XPATH,value='//span[@class="txt"]/a').click()
# #https://music.163.com/#/song?id=298317
# #/song?id=298317
# time.sleep(2)
# windows=web.window_handles
# web.switch_to.window(windows[-1])
# web.switch_to.frame('contentFrame')
# name=web.find_element(by=By.XPATH,value='//div[@class="tit"]/em').text
# print(name)
# html=web.page_source

# tree=etree.HTML(html)
# obj=tree.xpath('//div[@class="cmmts j-flag"]/div')

# for row in obj:
#     user=row.xpath('./div[2]/div[1]/div//text()')[0].strip()
#     comment=row.xpath('./div[2]/div[1]/div/text()')[0].strip()
#     content=user+':'+comment
#     print(content)
# Out:
# 屋顶
# 战五渣的逆袭:：小时候还有屋顶，现在就剩天台了。
# 煎鸡蛋水母:：经常一个人唱男女声部…也是服了自己…
# icy雪糕:：在屋顶藏着你的哥
# 车厘情果:：每天一瓶百事可乐，瓶子上必须是周杰伦，买的衣服全是美特斯邦威 ，电话卡要办动感地带。刘海儿一直盖着眼睛，说话故意讲不清楚。作业可以不写但是歌词一定要抄。恋爱的时候听周杰伦，失恋的时候听周杰伦，逃课听周杰伦，睡觉听周杰伦
# 不腻心:：徐州站。歌迷点歌：霍元甲。 歌迷：我的一岁儿子很喜欢这首歌。 周杰伦：我不相信你这么年轻是妈妈了。歌迷：我也不相信你已经是爸爸了。
# 辞藻在这里会见:：网易终于可以听周杰伦的歌了，感谢政府的反垄断
# 913176167:：突然好想我女朋友，也不知道她吃没吃饭，今天上班了没，累不累，忙不忙，住在哪里，多大了，叫什么。
# 晨霜攀黛瓦_丶:：一直想遇到一个能合唱这首歌的人，然而一直未遇到
# cocacala1886:：网易到底什么时候才能听周杰伦的歌
# 风泽H:：一天，小明问爸爸：爸爸，为什么电视看不了？爸爸：昨晚不知道是谁用天线排成了爱你的形状……
# 带珍珠耳环的小胖纸:：吴宗宪，你发现了一颗永恒之星
# 许升的圈外女友:：昨晚看2016地表最强杰伦演唱会太原站，简直要哭出来，录音机→复读机→单片机→CD机→mp3→mp4→ipod→PC，各种装备和杰伦一起走过16年。高中时，偶像是一张海报，你在墙上，我在望。大学时，偶像是一张专辑，你在歌里，我跟着唱。今天，偶像是一张门票，你在舞台称王，我在台下热泪盈眶
# 杏树会开:：这是云村唯一一首周董的歌？
# 栗子不需要春天:：对于我来说网易唯一缺点就是没有周杰伦的歌
# Biaomimi:：对于我来说网易唯一缺点就是没有周杰伦的歌
# peculiar_jay:：帅哥！dddd
# Larry玩意:：求！
# 基督山的爵:：拓海是你吗？
# _周沅沅:：我要我要
# 明天见1127:：400+jaychou的歌要的私我
# 丶淦林北:：哥给我也传传
# 丶淦林北:：我也要求求了
# ys170033:：可以私一下下嘛
# 韩国大鸡排:：6
# 未逢惆怅:：帮传云盘
# 深陷少女篇章y:：不会还有人不会用网盘上传周董的歌吧
# 垫底球王:：为什么大家动态都没有说了再见啊啊啊
# -SERENR:：要周董歌＋我哦
# ...

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from lxml import etree
# import time

# web=webdriver.Chrome()
# url='https://music.163.com/#/artist?id=6452'
# web.get(url)
# time.sleep(3)

# web.switch_to.frame('contentFrame')
# time.sleep(1)
# web.find_element(by=By.XPATH,value='//span[@class="txt"]/a').click()
# time.sleep(2)
# windows=web.window_handles
# web.switch_to.window(windows[-1])
# web.switch_to.frame('contentFrame')
# name=web.find_element(by=By.XPATH,value='//div[@class="tit"]/em').text
# print(name)
# html=web.page_source
# tree=etree.HTML(html)
# obj=tree.xpath('//div[@class="cmmts j-flag"]/div')
# f=open(f"E:\\an\\pclass\\selenium实验\\{name}.txt",mode="a",encoding="utf-8")
# for row in obj:
#     user=row.xpath('./div[2]/div[1]/div//text()')[0].strip()
#     comment=row.xpath('./div[2]/div[1]/div/text()')[0].strip()
#     content=user+':'+comment
#     print(content)
#     f.write(content+'\n')
# f.close()
# Out:
# 屋顶

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from lxml import etree
# import time
# import csv

# web=webdriver.Chrome()
# url='https://music.163.com/#/artist?id=6452'
# web.get(url)
# time.sleep(4)
# web.switch_to.frame('contentFrame')
# time.sleep(1)
# text=web.page_source
# # print(text)
# tree=etree.HTML(text)
# info=[]
# for row in tree.xpath('//*[@class="j-flag"]//tr'):
#     m_name=row.xpath('.//span[@class="txt"]/a/b/@title')[0]
#     m_url='https://music.163.com/#' + row.xpath('.//span[@class="txt"]/a/@href')[0]
#     info.append([m_name,m_url])
    
# # #将爬取的内容存入csv文件
# path="E:\\an\\pclass\\爬的内容\\xxtest.csv"
# with open(path,"w+",newline='',encoding="utf-8-sig") as f:
#     csv_write=csv.writer(f)
#     csv_write.writerow(["歌曲名称","歌曲链接"])
#     csv_write.writerows(info)
# Out:
# 屋顶 https://music.163.com/#/song?id=298317
# 布拉格广场 https://music.163.com/#/song?id=210049
# 刀马旦 https://music.163.com/#/song?id=255020
# 手牵手 - (2003年抗非典公益歌曲) https://music.163.com/#/song?id=5268423
# 屋顶 https://music.163.com/#/song?id=5257138
# 骑士精神 https://music.163.com/#/song?id=209760
# 布拉格广场 https://music.163.com/#/song?id=29393641
# 骑士精神 https://music.163.com/#/song?id=210062
# 祝我生日快乐 (Live) https://music.163.com/#/song?id=298101
# 海盗 https://music.163.com/#/song?id=209917
# 布拉格广场 https://music.163.com/#/song?id=209756
# 屋顶 https://music.163.com/#/song?id=298110
# 黄浦江深 https://music.163.com/#/song?id=288371
# 康定情歌 https://music.163.com/#/song?id=288382
# 海盗 https://music.163.com/#/song?id=406346416
# 布拉格广场 https://music.163.com/#/song?id=5234479
# 夜店咖 https://music.163.com/#/song?id=29808783
# 刀马旦 https://music.163.com/#/song?id=186064
# 布拉格广场 https://music.163.com/#/song?id=400162703
# 刀马旦 https://music.163.com/#/song?id=25640004
# 刀马旦 https://music.163.com/#/song?id=254832
# ...

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from lxml import etree
# import time
# import csv

# web=webdriver.Chrome()
# url='https://music.163.com/#/artist?id=6452'
# web.get(url)
# time.sleep(4)
# web.switch_to.frame('contentFrame')
# time.sleep(1)
# text=web.page_source
# # print(text)
# tree=etree.HTML(text)
# info=[]
# for row in tree.xpath('//*[@class="j-flag"]//tr'):
#     m_name=row.xpath('.//span[@class="txt"]/a/b/@title')[0]
#     m_url='https://music.163.com/#' + row.xpath('.//span[@class="txt"]/a/@href')[0]
#     info.append([m_name,m_url])
# #把数据存入CSV文件
# path="C:\\pachong\\选修\\期末.csv"
# with open(path,"w+",newline='',encoding="utf-8-sig") as f:
#     csv_write=csv.writer(f)
#     csv_write.writerow(["歌曲名称","歌曲链接"])
#     csv_write.writerows(info)
